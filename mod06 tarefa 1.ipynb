# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd

dataframe = pd.read_csv('SINASC_RO_2019.csv')

# Selecionando as colunas de interesse
colunas_interesse = ["SEXO" ,"APGAR1" , "ESTCIVMAE", "GESTACAO", "APGAR5"]
dataframe_interesse = dataframe[colunas_interesse]

valores_missing = dataframe_interesse.isna().sum()

print(valores_missing)
# Out:
# SEXO            4
# APGAR1         96
# ESTCIVMAE     317
# GESTACAO     1232
# APGAR5        103
# dtype: int64

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
import matplotlib.pyplot as plt
import numpy as np 


variavel= ["APGAR1" , "APGAR5", "SEXO"  , "GESTACAO","ESTCIVMAE"]
plt.plot(variavel)

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
df = pd.dataframe = ["APGAR1" , "APGAR5", "SEXO"  , "GESTACAO","ESTCIVMAE"]
df

df.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 df = pd.dataframe = ["APGAR1" , "APGAR5", "SEXO"  , "GESTACAO","ESTCIVMAE"]
#       2 df
# ----> 4 df.plot.bar()
#
# AttributeError: 'list' object has no attribute 'plot'

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS
