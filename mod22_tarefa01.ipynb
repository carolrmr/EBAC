# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
from pandas_datareader import data as web
import plotly.express as px 
from plotly import graph_objects
import yfinance as yf
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import mplfinance as mpf

import pandas as pd
import numpy as np

yf.pdr_override()
ativos = ["^BVSP", "ITUB3.SA","PETR4.SA"]
start_date = "2022-01-01"
end_date = "2023-01-01"

# Obter dados do Yahoo Finance usando pandas_datareader
data = web.get_data_yahoo(ativos, start=start_date, end=end_date)

# Exibir os dados
print(data)
# Out:
# [*********************100%%**********************]  3 of 3 completed
#             Adj Close                           Close
#              ITUB3.SA   PETR4.SA     ^BVSP   ITUB3.SA   PETR4.SA     ^BVSP
# Date
# 2022-01-03  17.706390  13.173102  103922.0  19.379999  29.090000  103922.0  \
# 2022-01-04  18.099257  13.222913  103514.0  19.809999  29.200001  103514.0
# 2022-01-05  17.733803  12.711205  101006.0  19.410000  28.070000  101006.0
# 2022-01-06  18.053577  12.702147  101561.0  19.760000  28.049999  101561.0
# 2022-01-07  18.336805  12.761018  102719.0  20.070000  28.180000  102719.0
# ...               ...        ...       ...        ...        ...       ...
# 2022-12-23  20.916758  19.464846  109698.0  21.860001  25.120001  109698.0
# 2022-12-26  20.648840  19.325369  108738.0  21.580000  24.940001  108738.0
# 2022-12-27  20.457474  19.457096  108347.0  21.379999  25.110001  108347.0
# 2022-12-28  20.983738  19.216887  110237.0  21.930000  24.799999  110237.0
# 2022-12-29  20.945465  18.984425  110031.0  21.889999  24.500000  110031.0
#
#                  High                             Low
#              ITUB3.SA   PETR4.SA     ^BVSP   ITUB3.SA   PETR4.SA     ^BVSP
# Date
# 2022-01-03  19.680000  29.219999  106125.0  19.040001  28.530001  103413.0  \
# 2022-01-04  19.850000  29.400000  104276.0  19.350000  28.910000  103096.0
# 2022-01-05  19.910000  29.270000  103514.0  19.379999  27.940001  100850.0
# 2022-01-06  19.799999  28.650000  102235.0  19.350000  27.840000  101000.0
# 2022-01-07  20.100000  28.290001  102719.0  19.459999  27.820000  101104.0
# ...               ...        ...       ...        ...        ...       ...
# 2022-12-23  22.070000  25.219999  109994.0  21.520000  24.129999  107552.0
# 2022-12-26  21.840000  25.299999  109755.0  21.379999  24.820000  108309.0
# 2022-12-27  21.650000  25.309999  109353.0  21.200001  24.549999  107418.0
# 2022-12-28  22.020000  25.320000  110536.0  21.379999  24.750000  108578.0
# 2022-12-29  22.219999  25.049999  111178.0  21.889999  24.430000  109560.0
#
#                  Open                        Volume
#              ITUB3.SA   PETR4.SA     ^BVSP ITUB3.SA  PETR4.SA     ^BVSP
# Date
# 2022-01-03  19.290001  28.540001  104823.0  1289800  52704700  11128500
# 2022-01-04  19.350000  29.160000  103922.0   984800  51739200  11491600
# 2022-01-05  19.780001  29.190001  103514.0   868800  78459800         0
# 2022-01-06  19.709999  28.290001  101006.0  1865700  61163100  11749200
# 2022-01-07  19.840000  28.110001  101561.0   985600  47507600  11733200
# ...               ...        ...       ...      ...       ...       ...
# 2022-12-23  21.570000  24.129999  107552.0   623700  68387900  12847100
# 2022-12-26  21.840000  25.120001  109699.0   149600  28765200   5219500
# 2022-12-27  21.650000  25.250000  108739.0   863300  50803200  11158100
# 2022-12-28  21.480000  25.100000  108578.0   594000  57293500  11193900
# 2022-12-29  22.000000  24.990000  110237.0  1321900  57901800  13389100
#
# [250 rows x 18 columns]

# %%
import yfinance as yf
import pandas as pd

# Lista de ativos
ativos = ["^BVSP", "ITUB3.SA", "PETR4.SA"]

# Baixar dados do Yahoo Finance
dados = yf.download(ativos, start="2022-01-01", end="2023-01-01")
fechamento = data["Adj Close"]

# Salvar os dados em um arquivo CSV
dados.to_csv("dados_ativos_yahoo.csv")

# Exibir os primeiros registros dos dados
print(dados.head())
# Out:
# [*********************100%%**********************]  3 of 3 completed
#             Adj Close                           Close
#              ITUB3.SA   PETR4.SA     ^BVSP   ITUB3.SA   PETR4.SA     ^BVSP
# Date
# 2022-01-03  17.706390  13.173102  103922.0  19.379999  29.090000  103922.0  \
# 2022-01-04  18.099257  13.222913  103514.0  19.809999  29.200001  103514.0
# 2022-01-05  17.733803  12.711205  101006.0  19.410000  28.070000  101006.0
# 2022-01-06  18.053577  12.702147  101561.0  19.760000  28.049999  101561.0
# 2022-01-07  18.336805  12.761018  102719.0  20.070000  28.180000  102719.0
#
#                  High                             Low
#              ITUB3.SA   PETR4.SA     ^BVSP   ITUB3.SA   PETR4.SA     ^BVSP
# Date
# 2022-01-03  19.680000  29.219999  106125.0  19.040001  28.530001  103413.0  \
# 2022-01-04  19.850000  29.400000  104276.0  19.350000  28.910000  103096.0
# 2022-01-05  19.910000  29.270000  103514.0  19.379999  27.940001  100850.0
# 2022-01-06  19.799999  28.650000  102235.0  19.350000  27.840000  101000.0
# 2022-01-07  20.100000  28.290001  102719.0  19.459999  27.820000  101104.0
#
#                  Open                        Volume
#              ITUB3.SA   PETR4.SA     ^BVSP ITUB3.SA  PETR4.SA     ^BVSP
# Date
# 2022-01-03  19.290001  28.540001  104823.0  1289800  52704700  11128500
# 2022-01-04  19.350000  29.160000  103922.0   984800  51739200  11491600
# 2022-01-05  19.780001  29.190001  103514.0   868800  78459800         0
# 2022-01-06  19.709999  28.290001  101006.0  1865700  61163100  11749200
# 2022-01-07  19.840000  28.110001  101561.0   985600  47507600  11733200

# %%
fechamento = data ['Adj Close'].isna().sum()

# %%
fechamento = data ['Adj Close']
fechamento.head()
# Out:
#              ITUB3.SA   PETR4.SA     ^BVSP
# Date
# 2022-01-03  17.706390  13.173102  103922.0
# 2022-01-04  18.099257  13.222913  103514.0
# 2022-01-05  17.733803  12.711205  101006.0
# 2022-01-06  18.053577  12.702147  101561.0
# 2022-01-07  18.336805  12.761018  102719.0

# %%
import pandas as pd
import pandas_datareader as pdr

# Baixar dados históricos 
data = web.get_data_yahoo("ITUB3.SA", start="2022-01-01", end="2023-07-20")

# Selecionar o fechamento
fechamento = data["Adj Close"]

# Renomear as colunas
fechamento.columns = ["data", "valor"]

# Visualizar os dados
print(fechamento.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2022-01-03    17.706392
# 2022-01-04    18.099258
# 2022-01-05    17.733805
# 2022-01-06    18.053577
# 2022-01-07    18.336809
# Name: Adj Close, dtype: float64

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
dados.to_csv('dados_ativos_yahoo.csv')

# %%
amp = dados ['High']-dados['Low']
amp.head(2)
# Out:
#             ITUB3.SA  PETR4.SA   ^BVSP
# Date
# 2022-01-03  0.639999  0.689999  2712.0
# 2022-01-04  0.500000  0.490000  1180.0

# %%
amp_vertical = amp.stack().reset_index()
amp_vertical.columns = ['data', 'ativo', 'amplitude']

amp_vertical.head()
# Out:
#         data     ativo    amplitude
# 0 2022-01-03  ITUB3.SA     0.639999
# 1 2022-01-03  PETR4.SA     0.689999
# 2 2022-01-03     ^BVSP  2712.000000
# 3 2022-01-04  ITUB3.SA     0.500000
# 4 2022-01-04  PETR4.SA     0.490000

# %%
fig = px.line(amp_vertical, x="data", y="amplitude", color='ativo', template='plotly_white')
fig.show()
