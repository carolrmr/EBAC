# %% [markdown]
# # Módulo 06 Tarefa 2

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('SINASC_RO_2019.csv')

plt.boxplot(df['IDADEMAE'])


plt.xlabel('Idade da Mãe')
plt.ylabel('Anos')
plt.title('Boxplot da Idade da Mãe')


plt.show()

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('SINASC_RO_2019.csv')

plt.boxplot(df['PESO'])

plt.xlabel('PESO DO BEBE')
plt.ylabel('KG')
plt.title('Boxplot peso do bebe ')

# Exibir o gráfico
plt.show()

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('SINASC_RO_2019.csv')

plt.hist(df['IDADEMAE'], bins=30)

plt.xlabel('Idade da Mãe')
plt.ylabel('Frequência')
plt.title('Histograma da Idade da Mãe')


plt.show()

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('SINASC_RO_2019.csv')


plt.hist(df['PESO'], bins=30)


plt.xlabel('PESO DO BEBE ')
plt.ylabel('Frequência')
plt.title('Histograma PESO DO BEBE ')

# Exibir o gráfico
plt.show()
